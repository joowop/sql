# %%
# import os
# os.chdir('C:\smartstore')

# %%
# !pyinstaller --noconsole --onefile SmartStore_DataLabeling.py
# Out:
# 651 INFO: PyInstaller: 5.7.0
# 651 INFO: Python: 3.8.0
# 651 INFO: Platform: Windows-10-10.0.22000-SP0
# 652 INFO: wrote C:\smartstore\SmartStore_DataLabeling.spec
# 677 INFO: UPX is not available.
# 681 INFO: Extending PYTHONPATH with paths
# ['C:\\smartstore']
# 1928 INFO: checking Analysis
# 1929 INFO: Building Analysis because Analysis-00.toc is non existent
# 1929 INFO: Initializing module dependency graph...
# 1932 INFO: Caching module graph hooks...
# 1941 WARNING: Several hooks defined for module 'numpy'. Please take care they do not conflict.
# 1951 INFO: Analyzing base_library.zip ...
# 5082 INFO: Loading module hook 'hook-encodings.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 6976 INFO: Loading module hook 'hook-pickle.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 7552 INFO: Loading module hook 'hook-heapq.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 8103 INFO: Caching module dependency graph...
# 8248 INFO: running Analysis Analysis-00.toc
# 8263 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by c:\users\joowo\appdata\local\programs\python\python38\python.exe
# 8495 INFO: Analyzing C:\smartstore\SmartStore_DataLabeling.py
# 8582 INFO: Loading module hook 'hook-pandas.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 11218 INFO: Loading module hook 'hook-platform.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 11325 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Python\\Python38\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 12429 INFO: Loading module hook 'hook-numpy._pytesttester.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 13504 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 13950 INFO: Loading module hook 'hook-xml.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 14566 INFO: Loading module hook 'hook-difflib.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 15203 INFO: Loading module hook 'hook-sysconfig.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 16807 INFO: Loading module hook 'hook-pytz.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 17303 INFO: Loading module hook 'hook-pkg_resources.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 20605 INFO: Loading module hook 'hook-scipy.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 20977 INFO: Loading module hook 'hook-pycparser.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 21575 INFO: Processing pre-find module path hook distutils from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 22353 INFO: Loading module hook 'hook-distutils.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 22398 INFO: Loading module hook 'hook-distutils.util.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 22657 INFO: Loading module hook 'hook-setuptools.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 26242 INFO: Loading module hook 'hook-importlib_metadata.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 26776 INFO: Loading module hook 'hook-packaging.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 27236 INFO: Loading module hook 'hook-jinja2.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 28784 INFO: Loading module hook 'hook-scipy.linalg.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 29140 INFO: Loading module hook 'hook-scipy.sparse.csgraph.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 30802 INFO: Loading module hook 'hook-matplotlib.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 31463 INFO: Processing pre-safe import module hook gi from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 31639 INFO: Loading module hook 'hook-PIL.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 31683 INFO: Loading module hook 'hook-PIL.Image.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 32659 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 32793 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 33289 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 34195 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 34862 INFO: Processing pre-safe import module hook six.moves from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 37222 INFO: Loading module hook 'hook-IPython.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 39949 INFO: Loading module hook 'hook-pygments.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 43866 INFO: Loading module hook 'hook-lib2to3.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 46277 INFO: Loading module hook 'hook-wcwidth.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 48522 INFO: Loading module hook 'hook-jedi.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 51117 INFO: Loading module hook 'hook-parso.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 52788 INFO: Loading module hook 'hook-sqlite3.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 53837 INFO: Loading module hook 'hook-nbformat.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 54570 INFO: Loading module hook 'hook-jsonschema.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 54727 INFO: Loading module hook 'hook-importlib_resources.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 55188 INFO: Processing pre-safe import module hook urllib3.packages.six.moves from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-urllib3.packages.six.moves.py'.
# 55718 INFO: Loading module hook 'hook-charset_normalizer.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 56172 INFO: Loading module hook 'hook-cryptography.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59455 INFO: Loading module hook 'hook-certifi.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 60266 INFO: Loading module hook 'hook-zmq.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 63721 INFO: Loading module hook 'hook-scipy.spatial.transform.rotation.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 67549 INFO: Loading module hook 'hook-pyarrow.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 70393 INFO: Loading module hook 'hook-pandas.plotting.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 71609 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 73761 INFO: Loading module hook 'hook-openpyxl.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 76998 INFO: Loading module hook 'hook-sqlalchemy.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 79922 INFO: Processing module hooks...
# 79926 WARNING: Hidden import "pyarrow.compat" not found!
# 80186 WARNING: Hidden import "importlib_resources.trees" not found!
# 80186 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 80187 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 80579 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 80579 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 80985 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 84001 INFO: Loading module hook 'hook-scipy.special._ellip_harm_2.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 84001 INFO: Loading module hook 'hook-scipy.special._ufuncs.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 84002 INFO: Loading module hook 'hook-scipy.stats._stats.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 84021 INFO: Loading module hook 'hook-setuptools.msvc.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 85491 INFO: Loading module hook 'hook-sqlalchemy.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 85731 INFO:   Found 4 sqlalchemy hidden imports
# 85732 WARNING: Hidden import "pysqlite2" not found!
# 85733 WARNING: Hidden import "MySQLdb" not found!
# 85733 WARNING: Hidden import "psycopg2" not found!
# 86917 INFO: Processing pre-safe import module hook win32com from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 87084 INFO: Loading module hook 'hook-win32com.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 87086 INFO: Loading module hook 'hook-pythoncom.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 87681 INFO: Loading module hook 'hook-pywintypes.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 89751 WARNING: Hidden import "sqlalchemy.sql.functions.func" not found!
# 89754 INFO: Loading module hook 'hook-_tkinter.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 89984 INFO: checking Tree
# 89984 INFO: Building Tree because Tree-00.toc is non existent
# 89984 INFO: Building Tree Tree-00.toc
# 90081 INFO: checking Tree
# 90081 INFO: Building Tree because Tree-01.toc is non existent
# 90082 INFO: Building Tree Tree-01.toc
# 90200 INFO: checking Tree
# 90200 INFO: Building Tree because Tree-02.toc is non existent
# 90200 INFO: Building Tree Tree-02.toc
# 90478 INFO: Looking for ctypes DLLs
# 90589 INFO: Analyzing run-time hooks ...
# 90606 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 90609 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 90611 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 90614 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_setuptools.py'
# 90615 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 90619 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 90621 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 90622 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 90624 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 90625 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 90626 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 90671 INFO: Looking for dynamic libraries
# c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\building\build_main.py:174: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\isolated\_child.py:94: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# 4335 INFO: Extra DLL search directories (AddDllDirectory): ['c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\numpy\\.libs', 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\pyzmq.libs', 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\scipy\\.libs']
# 4335 INFO: Extra DLL search directories (PATH): ['C:\\Users\\joowo\\Downloads\\cmder\\vendor\\conemu-maximus5\\ConEmu\\Scripts', 'C:\\Users\\joowo\\Downloads\\cmder\\vendor\\conemu-maximus5', 'C:\\Users\\joowo\\Downloads\\cmder\\vendor\\conemu-maximus5\\ConEmu', 'C:\\Program Files\\Amazon Corretto\\jdk11.0.14_10\\bin', 'C:\\app\\joowo\\product\\18.0.0\\dbhomeXE\\bin', 'C:\\WINDOWS\\system32', 'C:\\WINDOWS', 'C:\\WINDOWS\\System32\\Wbem', 'C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\', 'C:\\WINDOWS\\System32\\OpenSSH\\', 'C:\\Users\\joowo\\flutter_windows_2.10.3-stable\\flutter\\bin', 'C:\\Program Files\\nodejs\\', 'C:\\Program Files\\Git\\cmd', 'C:\\Program Files\\MySQL\\MySQL Server 8.0\\bin', 'C:\\Program Files\\MongoDB\\Server\\5.0\\bin', 'C:\\Program Files\\Docker\\Docker\\resources\\bin', 'C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\', 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Python\\Python38\\Scripts\\', 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Python\\Python38\\', 'C:\\Users\\joowo\\AppData\\Local\\Microsoft\\WindowsApps', 'C:\\Program Files\\Bandizip\\', 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Microsoft VS Code\\bin', 'C:\\Users\\joowo\\AppData\\Roaming\\npm', 'C:\\Users\\joowo\\AppData\\Local\\afreeca', 'C:\\Program Files\\Git\\mingw64\\bin', 'C:\\Program Files\\Git\\usr\\bin', 'C:\\Users\\joowo\\Downloads\\cmder\\vendor\\bin', 'C:\\Users\\joowo\\Downloads\\cmder']
# 97360 INFO: Looking for eggs
# 97360 INFO: Using Python library c:\users\joowo\appdata\local\programs\python\python38\python38.dll
# 97360 INFO: Found binding redirects:
# []
# 97385 INFO: Warnings written to C:\smartstore\build\SmartStore_DataLabeling\warn-SmartStore_DataLabeling.txt
# 97791 INFO: Graph cross-reference written to C:\smartstore\build\SmartStore_DataLabeling\xref-SmartStore_DataLabeling.html
# 97990 INFO: checking PYZ
# 97990 INFO: Building PYZ because PYZ-00.toc is non existent
# 97990 INFO: Building PYZ (ZlibArchive) C:\smartstore\build\SmartStore_DataLabeling\PYZ-00.pyz
# 101806 INFO: Building PYZ (ZlibArchive) C:\smartstore\build\SmartStore_DataLabeling\PYZ-00.pyz completed successfully.
# 101883 INFO: checking PKG
# 101883 INFO: Building PKG because PKG-00.toc is non existent
# 101883 INFO: Building PKG (CArchive) SmartStore_DataLabeling.pkg
# 132425 INFO: Building PKG (CArchive) SmartStore_DataLabeling.pkg completed successfully.
# 132526 INFO: Bootloader c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 132526 INFO: checking EXE
# 132527 INFO: Building EXE because EXE-00.toc is non existent
# 132527 INFO: Building EXE from EXE-00.toc
# 132527 INFO: Copying bootloader EXE to C:\smartstore\dist\SmartStore_DataLabeling.exe.notanexecutable
# 132535 INFO: Copying icon to EXE
# 132536 INFO: Copying icons from ['c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\bootloader\\images\\icon-windowed.ico']
# 132537 INFO: Writing RT_GROUP_ICON 0 resource with 104 bytes
# 132537 INFO: Writing RT_ICON 1 resource with 3752 bytes
# 132537 INFO: Writing RT_ICON 2 resource with 2216 bytes
# 132537 INFO: Writing RT_ICON 3 resource with 1384 bytes
# 132537 INFO: Writing RT_ICON 4 resource with 38188 bytes
# 132537 INFO: Writing RT_ICON 5 resource with 9640 bytes
# 132537 INFO: Writing RT_ICON 6 resource with 4264 bytes
# 132537 INFO: Writing RT_ICON 7 resource with 1128 bytes
# 132542 INFO: Copying 0 resources to EXE
# 132542 INFO: Embedding manifest in EXE
# 132543 INFO: Updating manifest in C:\smartstore\dist\SmartStore_DataLabeling.exe.notanexecutable
# 132544 INFO: Updating resource type 24 name 1 language 0
# 132549 INFO: Appending PKG archive to EXE
# 132640 INFO: Fixing EXE headers
# 133450 INFO: Building EXE from EXE-00.toc completed successfully.

# %%
import sys
sys.path.insert(0, '../modules')
import pandas as pd
import pymysql
from callDB import DBHelper as db
from truckEDA import EDAHelper
from dotenv import dotenv_values
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from datetime import datetime as dt
import os
import glob
import re
from IPython import get_ipython
import pandas as pd
import datetime
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.dates as mdates
from dateutil import rrule
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.3f}'.format
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# 필요시 run 전체 데이터프레임 보여주는 옵션
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)


config = dotenv_values("../modules/.env")

server = "REL"
f = db(config, server)
eda = EDAHelper()

# 업로드 거래 중  CURRENT_DATE(),
data =  f.table('SELECT MCR_ID, MCR_DEAL_DT, MCR_REG_DT \
FROM TB_MYCAR  \
WHERE MCR_STATE != "H" \
ORDER BY MCR_REG_DT DESC;')

writer = pd.ExcelWriter('smartstore_modify.xlsx', engine='openpyxl')
pd.concat([
    data,
]).to_excel(writer, 'store', index=False)

writer.save()

# %%
# import sys
# sys.path.insert(0, '../modules')
# import pandas as pd
# import pymysql
# from callDB import DBHelper as db
# from truckEDA import EDAHelper
# from dotenv import dotenv_values
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
# from datetime import datetime as dt
# import os
# import glob
# import re
# from IPython import get_ipython
# import pandas as pd
# import datetime
# from tqdm.notebook import tqdm
# import numpy as np
# import matplotlib.dates as mdates
# from dateutil import rrule
# pd.set_option('display.max_rows', 300)
# pd.options.display.float_format = '{:,.3f}'.format
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# # 필요시 run 전체 데이터프레임 보여주는 옵션
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 500)

# config = dotenv_values("../modules/.env")

# server = "REL"
# f = db(config, server)
# eda = EDAHelper()

# # 업로드 거래 중  CONVERT(CHAR(10), DATETIME, 23)
# data =  f.table('SELECT m.MCR_REG_DT, m.MCR_ID, m.MCR_SCD, m.MCR_BRAND_CD, m.MCR_MODEL_CD, m.MCR_LCD, m.MCR_PRICE, m.MCR_STATE, m.MCR_IMG1, m.MCR_IMG2,m.MCR_IMG3, m.MCR_IMG4, m.MCR_IMG5, m.MCR_IMG6, m.MCR_IMG7, m.MCR_IMG8, m.MCR_IMG9, m.MCR_IMG10, m.MCR_TON, m.MCR_YEAR_MM, m.MCR_KM, m.MCR_DESC \
# FROM TB_MYCAR AS m \
# LEFT OUTER JOIN  \
# TB_DEALER AS d  \
# ON m.DAL_ID = d.DAL_ID \
# WHERE m.MCR_STATE = "C" \
# ORDER BY MCR_REG_DT DESC;')

# def iTruck_data(data):
#     based_data = data.astype('str')
#     # data['MCR_REG_DT'] = data['MCR_REG_DT'].str.slice(0, 10)
#     # based_data = data[data['MCR_REG_DT'].isin(data['CURRENT_DATE()'])]
#     based_data = eda.rename_column(based_data, ['TB_MYCAR', 'TB_DEALER'])
#     based_data['대분류'] = eda.rename_value(based_data['대분류'])
#     based_data['소분류'] = eda.rename_value(based_data['소분류'])
#     based_data['브랜드'] = eda.rename_value(based_data['브랜드'])
#     based_data['모델'] = eda.rename_value(based_data['모델'])
#     based_data['등록일자'] = pd.to_datetime(based_data['등록일자'], format='%Y-%m-%d', errors='coerce')

#     based_data['상품명'] = based_data['브랜드'] + " " + based_data['모델'] + " " + based_data['소분류'] + " " + based_data['톤수'] + "톤"
#     based_data["상품명"]= based_data["상품명"].str.replace("0톤", "", )
#     based_data['추가이미지'] = based_data['이미지2'] + "\n" + based_data['이미지3'] + "\n" + based_data['이미지4'] + "\n" + based_data['이미지5'] + "\n" + based_data['이미지6'] + "\n" + based_data['이미지7'] + "\n" + based_data['이미지8'] + "\n" + based_data['이미지9']
#     # based_data['추가이미지'] = based_data['추가이미지'].replace(np.nan, '') 
#     based_data["추가이미지"]= based_data["추가이미지"].str.replace("None", "", )
#     based_data['상세설명'] = "<h1><b>연식 : " + based_data['연식'] + "</b></h1><br><h1><b>톤수 : " + based_data['톤수'] + "</b></h1><br><h1><b>주행거리 : " + based_data['주행거리'] + "</b></h1><br><h1><b>" + based_data['상세설명'] + "</b></h1><br> \n<img src=\"" + based_data['이미지1'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지2'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지3'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지4'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지5'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지6'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지7'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지8'] + "\" width=\"800\" height=\"auto\"> \n<img src=\"" + based_data['이미지9'] + "\" width=\"800\" height=\"auto\">"
#     based_data["상세설명"]= based_data["상세설명"].str.replace("<img src=\"None\" width=\"800\" height=\"auto\">", "", )
#     based_data["상세설명"]= based_data["상세설명"].str.replace("직거래", "거래", )
#     based_data.rename(columns = {'내차사기 아이디':'판매자 상품코드','브랜드':'제조사' ,'가격':'판매가', '이미지1':'대표이미지'},inplace=True)
#     based_data = based_data.drop(['이미지2', '이미지3', '이미지4', '이미지5', '이미지6', '이미지7', '이미지8', '이미지9', '이미지10', '소분류', '모델', '대분류', '매물상태', '톤수', '연식', '주행거리'], axis=1)
#     return based_data

# df3 = pd.read_excel('smartstore_test.xlsx', sheet_name="일괄등록", engine='openpyxl')
# df3 = df3.rename(columns=df3.iloc[0])
# df3 = df3.drop(index=[0,1,2,3,4,5], axis=0)

# def upload(df3, based_data):
#     df_12_axis0 = pd.concat([df3, based_data]) # row bind : axis = 0, default
#     df_12_axis0["재고수량"] = df_12_axis0["재고수량"].replace(np.nan, 1)
#     df_12_axis0["카테고리코드"] = df_12_axis0["카테고리코드"].replace(np.nan, '50004126')
#     df_12_axis0["A/S 전화번호"] = df_12_axis0["A/S 전화번호"].replace(np.nan, '02-4949-8989')
#     df_12_axis0["A/S 안내"] = df_12_axis0["A/S 안내"].replace(np.nan, '02-4949-8989')
#     df_12_axis0["원산지코드"] = df_12_axis0["원산지코드"].replace(np.nan, '03')
#     df_12_axis0["상품상태"] = df_12_axis0["상품상태"].replace(np.nan, '중고상품')
#     df_12_axis0['판매가'] =  df_12_axis0['판매가'] + "0000"
#     df_12_axis0 = df_12_axis0.replace(np.nan, '')
#     return df_12_axis0

# based_data = iTruck_data(data)
# df_12_axis0 = upload(df3, based_data)
# writer = pd.ExcelWriter('smartstore_upload.xlsx', engine='openpyxl')
# pd.concat([
#     df_12_axis0,
# ]).to_excel(writer, 'store', index=False)

# writer.save()
# Out:
# C:\Users\joowo\AppData\Local\Temp\ipykernel_22256\2829945504.py:23: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [332], in <cell line: 33>()
#      30 config = dotenv_values("../modules/.env")
#      32 server = "REL"
# ---> 33 f = db(config, server)
#      34 eda = EDAHelper()
#      36 # 업로드 거래 중  CONVERT(CHAR(10), DATETIME, 23)
#
# File ~\iTruck\da_2\assets\modules\callDB.py:20, in DBHelper.__init__(self, config, server)
#      18 if server == "REL":  # 실서버
#      19     self.host = "3.35.245.243"
# ---> 20     self.user = config["MYSQL_LIVE_USER"]
#      21     self.password = config["MYSQL_LIVE_PWD"]
#      22 elif server == "DEV":  # 개발서버
#
# KeyError: 'MYSQL_LIVE_USER'
# 596 INFO: PyInstaller: 5.7.0
# 596 INFO: Python: 3.8.0
# 597 INFO: Platform: Windows-10-10.0.22000-SP0
# 597 INFO: wrote C:\smartstore\SmartStore_DataLabeling.spec
# 621 INFO: UPX is not available.
# 623 INFO: Extending PYTHONPATH with paths
# ['C:\\smartstore']
# 1770 INFO: checking Analysis
# 1770 INFO: Building Analysis because Analysis-00.toc is non existent
# 1770 INFO: Initializing module dependency graph...
# 1773 INFO: Caching module graph hooks...
# 1782 WARNING: Several hooks defined for module 'numpy'. Please take care they do not conflict.
# 1792 INFO: Analyzing base_library.zip ...
# 4241 INFO: Loading module hook 'hook-heapq.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 4672 INFO: Loading module hook 'hook-encodings.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 6465 INFO: Loading module hook 'hook-pickle.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 7682 INFO: Caching module dependency graph...
# 7823 INFO: running Analysis Analysis-00.toc
# 7839 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by c:\users\joowo\appdata\local\programs\python\python38\python.exe
# 8123 INFO: Analyzing C:\smartstore\SmartStore_DataLabeling.py
# 8213 INFO: Loading module hook 'hook-pandas.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 10554 INFO: Loading module hook 'hook-platform.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 10652 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Python\\Python38\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 11597 INFO: Loading module hook 'hook-numpy._pytesttester.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 12594 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 13026 INFO: Loading module hook 'hook-xml.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 13661 INFO: Loading module hook 'hook-difflib.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 14363 INFO: Loading module hook 'hook-sysconfig.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 16066 INFO: Loading module hook 'hook-pytz.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 16570 INFO: Loading module hook 'hook-pkg_resources.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 20090 INFO: Loading module hook 'hook-scipy.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 20473 INFO: Loading module hook 'hook-pycparser.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 21000 INFO: Processing pre-find module path hook distutils from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 21785 INFO: Loading module hook 'hook-distutils.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 21827 INFO: Loading module hook 'hook-distutils.util.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 22094 INFO: Loading module hook 'hook-setuptools.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 25705 INFO: Loading module hook 'hook-importlib_metadata.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 26214 INFO: Loading module hook 'hook-packaging.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 26676 INFO: Loading module hook 'hook-jinja2.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 28237 INFO: Loading module hook 'hook-scipy.linalg.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 28612 INFO: Loading module hook 'hook-scipy.sparse.csgraph.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 30355 INFO: Loading module hook 'hook-matplotlib.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 31008 INFO: Processing pre-safe import module hook gi from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 31202 INFO: Loading module hook 'hook-PIL.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 31256 INFO: Loading module hook 'hook-PIL.Image.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 32339 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 32489 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 33082 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 34176 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 34915 INFO: Processing pre-safe import module hook six.moves from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 37374 INFO: Loading module hook 'hook-IPython.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 40002 INFO: Loading module hook 'hook-pygments.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 43589 INFO: Loading module hook 'hook-lib2to3.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 46145 INFO: Loading module hook 'hook-wcwidth.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 48683 INFO: Loading module hook 'hook-jedi.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 51398 INFO: Loading module hook 'hook-parso.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 53103 INFO: Loading module hook 'hook-sqlite3.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 54140 INFO: Loading module hook 'hook-nbformat.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 55008 INFO: Loading module hook 'hook-jsonschema.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 55196 INFO: Loading module hook 'hook-importlib_resources.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 55809 INFO: Processing pre-safe import module hook urllib3.packages.six.moves from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-urllib3.packages.six.moves.py'.
# 56379 INFO: Loading module hook 'hook-charset_normalizer.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 56749 INFO: Loading module hook 'hook-cryptography.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 60344 INFO: Loading module hook 'hook-certifi.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61250 INFO: Loading module hook 'hook-zmq.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 64984 INFO: Loading module hook 'hook-scipy.spatial.transform.rotation.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 69141 INFO: Loading module hook 'hook-pyarrow.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 71878 INFO: Loading module hook 'hook-pandas.plotting.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 73143 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 75214 INFO: Loading module hook 'hook-openpyxl.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 78817 INFO: Loading module hook 'hook-sqlalchemy.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 82041 INFO: Processing module hooks...
# 82046 WARNING: Hidden import "pyarrow.compat" not found!
# 82341 WARNING: Hidden import "importlib_resources.trees" not found!
# 82341 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 82341 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 82761 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 82761 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 83286 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 86462 INFO: Loading module hook 'hook-scipy.special._ellip_harm_2.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 86463 INFO: Loading module hook 'hook-scipy.special._ufuncs.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 86464 INFO: Loading module hook 'hook-scipy.stats._stats.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 86497 INFO: Loading module hook 'hook-setuptools.msvc.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 88196 INFO: Loading module hook 'hook-sqlalchemy.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 88523 INFO:   Found 4 sqlalchemy hidden imports
# 88525 WARNING: Hidden import "pysqlite2" not found!
# 88526 WARNING: Hidden import "MySQLdb" not found!
# 88527 WARNING: Hidden import "psycopg2" not found!
# 89913 INFO: Processing pre-safe import module hook win32com from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 90101 INFO: Loading module hook 'hook-win32com.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 90103 INFO: Loading module hook 'hook-pythoncom.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 90770 INFO: Loading module hook 'hook-pywintypes.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 93120 WARNING: Hidden import "sqlalchemy.sql.functions.func" not found!
# 93123 INFO: Loading module hook 'hook-_tkinter.py' from 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks'...
# 93347 INFO: checking Tree
# 93347 INFO: Building Tree because Tree-00.toc is non existent
# 93347 INFO: Building Tree Tree-00.toc
# 93459 INFO: checking Tree
# 93459 INFO: Building Tree because Tree-01.toc is non existent
# 93459 INFO: Building Tree Tree-01.toc
# 93611 INFO: checking Tree
# 93611 INFO: Building Tree because Tree-02.toc is non existent
# 93612 INFO: Building Tree Tree-02.toc
# 93958 INFO: Looking for ctypes DLLs
# 94043 INFO: Analyzing run-time hooks ...
# 94062 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 94067 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 94069 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 94073 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_setuptools.py'
# 94076 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 94081 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 94085 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 94088 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 94091 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 94093 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 94095 INFO: Including run-time hook 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 94156 INFO: Looking for dynamic libraries
# c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\building\build_main.py:174: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\isolated\_child.py:94: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# 4845 INFO: Extra DLL search directories (AddDllDirectory): ['c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\numpy\\.libs', 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\pyzmq.libs', 'c:\\users\\joowo\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\scipy\\.libs']
# 4845 INFO: Extra DLL search directories (PATH): ['C:\\Users\\joowo\\Downloads\\cmder\\vendor\\conemu-maximus5\\ConEmu\\Scripts', 'C:\\Users\\joowo\\Downloads\\cmder\\vendor\\conemu-maximus5', 'C:\\Users\\joowo\\Downloads\\cmder\\vendor\\conemu-maximus5\\ConEmu', 'C:\\Program Files\\Amazon Corretto\\jdk11.0.14_10\\bin', 'C:\\app\\joowo\\product\\18.0.0\\dbhomeXE\\bin', 'C:\\WINDOWS\\system32', 'C:\\WINDOWS', 'C:\\WINDOWS\\System32\\Wbem', 'C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\', 'C:\\WINDOWS\\System32\\OpenSSH\\', 'C:\\Users\\joowo\\flutter_windows_2.10.3-stable\\flutter\\bin', 'C:\\Program Files\\nodejs\\', 'C:\\Program Files\\Git\\cmd', 'C:\\Program Files\\MySQL\\MySQL Server 8.0\\bin', 'C:\\Program Files\\MongoDB\\Server\\5.0\\bin', 'C:\\Program Files\\Docker\\Docker\\resources\\bin', 'C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\', 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Python\\Python38\\Scripts\\', 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Python\\Python38\\', 'C:\\Users\\joowo\\AppData\\Local\\Microsoft\\WindowsApps', 'C:\\Program Files\\Bandizip\\', 'C:\\Users\\joowo\\AppData\\Local\\Programs\\Microsoft VS Code\\bin', 'C:\\Users\\joowo\\AppData\\Roaming\\npm', 'C:\\Users\\joowo\\AppData\\Local\\afreeca', 'C:\\Program Files\\Git\\mingw64\\bin', 'C:\\Program Files\\Git\\usr\\bin', 'C:\\Users\\joowo\\Downloads\\cmder\\vendor\\bin', 'C:\\Users\\joowo\\Downloads\\cmder']
# 101361 INFO: Looking for eggs
# 101361 INFO: Using Python library c:\users\joowo\appdata\local\programs\python\python38\python38.dll
# 101361 INFO: Found binding redirects:
# []
# 101386 INFO: Warnings written to C:\smartstore\build\SmartStore_DataLabeling\warn-SmartStore_DataLabeling.txt
# 101801 INFO: Graph cross-reference written to C:\smartstore\build\SmartStore_DataLabeling\xref-SmartStore_DataLabeling.html
# 102020 INFO: checking PYZ
# 102021 INFO: Building PYZ because PYZ-00.toc is non existent
# 102021 INFO: Building PYZ (ZlibArchive) C:\smartstore\build\SmartStore_DataLabeling\PYZ-00.pyz
# 105711 INFO: Building PYZ (ZlibArchive) C:\smartstore\build\SmartStore_DataLabeling\PYZ-00.pyz completed successfully.
# Traceback (most recent call last):
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\joowo\AppData\Local\Programs\Python\Python38\Scripts\pyinstaller.exe\__main__.py", line 7, in <module>
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\__main__.py", line 194, in _console_script_run
#     run()
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\__main__.py", line 180, in run
#     run_build(pyi_config, spec_file, **vars(args))
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\__main__.py", line 61, in run_build
#     PyInstaller.building.build_main.main(pyi_config, spec_file, **kwargs)
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\building\build_main.py", line 971, in main
#     build(specfile, distpath, workpath, clean_build)
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\building\build_main.py", line 893, in build
#     exec(code, spec_namespace)
#   File "C:\smartstore\SmartStore_DataLabeling.spec", line 24, in <module>
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\building\api.py", line 517, in __init__
#     self.manifest = winmanifest.create_manifest(
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\utils\win32\winmanifest.py", line 1011, in create_manifest
#     manifest = ManifestFromXMLFile(filename)
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\utils\win32\winmanifest.py", line 971, in ManifestFromXMLFile
#     manifest.parse(filename_or_file)
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\site-packages\PyInstaller\utils\win32\winmanifest.py", line 702, in parse
#     domtree = minidom.parse(filename_or_file)
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\xml\dom\minidom.py", line 1959, in parse
#     return expatbuilder.parse(file)
#   File "c:\users\joowo\appdata\local\programs\python\python38\lib\xml\dom\expatbuilder.py", line 910, in parse
#     with open(file, 'rb') as fp:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\smartstore\\build\\SmartStore_DataLabeling\\SmartStore_DataLabeling.exe.manifest'
